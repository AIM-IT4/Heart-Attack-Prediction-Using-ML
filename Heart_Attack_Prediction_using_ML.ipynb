# %%
from pycaret.datasets import get_data
df = get_data('heart')
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3   56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4   57    0   0     120   354    0  ...     1      0.6    2    0      2       1
#
# [5 rows x 14 columns]

# %%
from pycaret.utils import enable_colab
enable_colab()
# Out:
# Colab mode enabled.

# %%
from pycaret.classification import *
exp_name = setup(data = df,  target = 'output')
# Out:
#                                Description             Value
# 0                               session_id               793
# 1                                   Target            output
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (303, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (212, 27)
# 12                    Transformed Test Set          (91, 27)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              3fc0
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %%
best_model = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.8452  0.9001  0.8682  0.8536
# ridge                    Ridge Classifier    0.8357  0.0000  0.8864  0.8304
# lda          Linear Discriminant Analysis    0.8310  0.9100  0.8864  0.8221
# et                 Extra Trees Classifier    0.8067  0.8737  0.8311  0.8188
# catboost              CatBoost Classifier    0.8024  0.8832  0.8250  0.8181
# rf               Random Forest Classifier    0.8019  0.8769  0.8235  0.8140
# nb                            Naive Bayes    0.7972  0.8864  0.8424  0.8013
# lightgbm  Light Gradient Boosting Machine    0.7840  0.8541  0.7727  0.8216
# xgboost         Extreme Gradient Boosting    0.7835  0.8524  0.7886  0.8053
# gbc          Gradient Boosting Classifier    0.7455  0.8376  0.7530  0.7751
# ada                  Ada Boost Classifier    0.7416  0.8016  0.7621  0.7749
# dt               Decision Tree Classifier    0.6935  0.6935  0.6992  0.7293
# knn                K Neighbors Classifier    0.6842  0.6884  0.7197  0.7129
# qda       Quadratic Discriminant Analysis    0.6325  0.6409  0.4962  0.7749
# svm                   SVM - Linear Kernel    0.5799  0.0000  0.5144  0.6084
# dummy                    Dummy Classifier    0.5329  0.5000  1.0000  0.5329
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.8587  0.6878  0.6917     0.422
# ridge     0.8546  0.6675  0.6747     0.013
# lda       0.8506  0.6577  0.6644     0.014
# et        0.8218  0.6103  0.6159     0.458
# catboost  0.8181  0.6028  0.6083     1.392
# rf        0.8162  0.6020  0.6063     0.459
# nb        0.8154  0.5915  0.6026     0.014
# lightgbm  0.7912  0.5686  0.5767     0.059
# xgboost   0.7931  0.5662  0.5725     6.350
# gbc       0.7613  0.4892  0.4927     0.085
# ada       0.7595  0.4794  0.4925     0.100
# dt        0.7085  0.3851  0.3905     0.016
# knn       0.7080  0.3661  0.3753     0.117
# qda       0.5700  0.2771  0.3137     0.016
# svm       0.4777  0.1499  0.1815     0.013
# dummy     0.6952  0.0000  0.0000     0.011

# %%
lr = create_model('lr')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.6818  0.7917  0.7500  0.6923  0.7200  0.3529  0.3545
# 1       0.8182  0.8833  0.8333  0.8333  0.8333  0.6333  0.6333
# 2       0.9524  0.9537  0.9167  1.0000  0.9565  0.9041  0.9083
# 3       0.7619  0.8364  0.8182  0.7500  0.7826  0.5205  0.5230
# 4       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 5       0.7143  0.7727  0.8182  0.6923  0.7500  0.4220  0.4301
# 6       0.9524  0.9727  1.0000  0.9167  0.9565  0.9041  0.9083
# 7       0.8571  0.9636  0.9091  0.8333  0.8696  0.7123  0.7156
# 8       0.8095  0.8818  0.8182  0.8182  0.8182  0.6182  0.6182
# 9       0.9048  0.9455  0.8182  1.0000  0.9000  0.8108  0.8257
# Mean    0.8452  0.9001  0.8682  0.8536  0.8587  0.6878  0.6917
# SD      0.1017  0.0754  0.0800  0.1154  0.0895  0.2062  0.2066

# %%
tuned_lr = tune_model(lr)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.6818  0.7833  0.7500  0.6923  0.7200  0.3529  0.3545
# 1       0.8636  0.8750  0.8333  0.9091  0.8696  0.7273  0.7303
# 2       0.9524  0.9537  0.9167  1.0000  0.9565  0.9041  0.9083
# 3       0.7143  0.8636  0.8182  0.6923  0.7500  0.4220  0.4301
# 4       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 5       0.7619  0.8091  0.8182  0.7500  0.7826  0.5205  0.5230
# 6       0.9524  0.9727  1.0000  0.9167  0.9565  0.9041  0.9083
# 7       0.8571  0.9364  0.9091  0.8333  0.8696  0.7123  0.7156
# 8       0.8095  0.8727  0.8182  0.8182  0.8182  0.6182  0.6182
# 9       0.9048  0.9636  0.8182  1.0000  0.9000  0.8108  0.8257
# Mean    0.8498  0.9030  0.8682  0.8612  0.8623  0.6972  0.7014
# SD      0.1014  0.0693  0.0800  0.1163  0.0891  0.2057  0.2059

# %%
plot_model(lr, plot = 'confusion_matrix')

# %%
plot_model(lr, plot = 'feature_all')

# %%
plot_model(lr, plot = 'error')

# %%
plot_model(lr, plot = 'auc')

# %%
pred_holdout = predict_model(lr)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  Logistic Regression    0.8132  0.9191  ...  0.8411  0.6149  0.6163
#
# [1 rows x 8 columns]

# %%
pred_unseen = predict_model(lr, data=None)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  Logistic Regression    0.8132  0.9191  ...  0.8411  0.6149  0.6163
#
# [1 rows x 8 columns]

# %%
pred_unseen
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#      age  trtbps   chol  thalachh  ...  thall_3  output  Label   Score
# 0   49.0   120.0  188.0     139.0  ...      1.0       0      0  0.7366
# 1   61.0   140.0  207.0     138.0  ...      1.0       0      0  0.9789
# 2   58.0   170.0  225.0     146.0  ...      0.0       0      0  0.9338
# 3   70.0   130.0  322.0     109.0  ...      0.0       0      0  0.9512
# 4   53.0   142.0  226.0     111.0  ...      1.0       1      0  0.8102
# ..   ...     ...    ...       ...  ...      ...     ...    ...     ...
# 86  65.0   140.0  417.0     157.0  ...      0.0       1      1  0.5831
# 87  58.0   130.0  197.0     131.0  ...      0.0       1      1  0.8664
# 88  62.0   120.0  267.0      99.0  ...      1.0       0      0  0.9935
# 89  60.0   150.0  258.0     157.0  ...      1.0       0      0  0.9601
# 90  57.0   128.0  303.0     159.0  ...      0.0       1      1  0.5492
#
# [91 rows x 30 columns]
